# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik2604/minorproject/blob/main/MinorProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import  imread 
from skimage.transform import resize

# %%
img = plt.imread('/content/drive/MyDrive/MachineLearning/DOG/5ec6c5a9f34d05585e018383.jpg')
plt.imshow(img)
img
# Out:
# array([[[117, 130,  77],
#         [112, 125,  72],
#         [110, 123,  70],
#         ...,
#         [112, 125,  72],
#         [113, 126,  73],
#         [117, 130,  77]],
#
#        [[115, 128,  75],
#         [110, 123,  70],
#         [108, 121,  68],
#         ...,
#         [107, 120,  67],
#         [109, 122,  69],
#         [113, 126,  73]],
#
#        [[113, 126,  73],
#         [108, 121,  68],
#         [106, 119,  66],
#         ...,
#         [105, 118,  65],
#         [107, 120,  67],
#         [111, 124,  71]],
#
#        ...,
#
#        [[113, 126,  73],
#         [108, 121,  68],
#         [106, 119,  66],
#         ...,
#         [105, 118,  65],
#         [105, 118,  65],
#         [110, 123,  70]],
#
#        [[114, 127,  74],
#         [110, 123,  70],
#         [108, 121,  68],
#         ...,
#         [105, 118,  65],
#         [106, 119,  66],
#         [111, 124,  71]],
#
#        [[116, 129,  76],
#         [112, 125,  72],
#         [110, 123,  70],
# ...

# %%
img.shape
# Out:
# (876, 700, 3)

# %%
import os
import numpy as np
datadir = '/content/drive/MyDrive/MachineLearning'
categories = ['CAT','DOG']
target = []
flat_data = []

for i in categories:
  path = os.path.join(datadir,i)
  print(path)
  for img in os.listdir(path):
    img_array = imread(os.path.join(path,img))


    
    img_resize = resize(img_array,(150,150,3))
    flat_data.append(np.ndarray.flatten(img_resize))
    target.append(i)
    plt.imshow(img_resize)
    plt.show()
# Out:
# /content/drive/MyDrive/MachineLearning/CAT
# /content/drive/MyDrive/MachineLearning/DOG

# %%
df = pd.DataFrame(flat_data)
df ['Target'] = target
df.head()
# Out:
#           0         1         2         3  ...     67497     67498     67499  Target
# 0  0.435660  0.423895  0.404288  0.443137  ...  0.633333  0.582353  0.547059     CAT
# 1  0.835294  0.725490  0.682353  0.835294  ...  0.713725  0.619608  0.596078     CAT
# 2  0.611765  0.243137  0.340444  0.615686  ...  0.631373  0.214092  0.301961     CAT
# 3  0.837255  0.849020  0.884314  0.827451  ...  0.812497  0.824261  0.843869     CAT
# 4  0.062745  0.043137  0.066667  0.066667  ...  0.170588  0.392157  0.431007     CAT
#
# [5 rows x 67501 columns]
